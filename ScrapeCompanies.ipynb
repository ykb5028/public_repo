# %%
import requests
from bs4 import BeautifulSoup

url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_by_revenue'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

# %%
table = soup.find_all('table')[0]

# %%
world_titles = soup.find_all('th')

# %%
world_table_titles = [title.text.strip() for title in world_titles]
six_titles = world_table_titles[1:7]
print(six_titles)
# Out:
# ['Name', 'Industry', 'Revenue', 'Profit', 'Employees', 'Headquarters[note 1]']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = six_titles)
df
# Out:
# Empty DataFrame
# Columns: [Name, Industry, Revenue, Profit, Employees, Headquarters[note 1]]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
for row in column_data[2:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data[:6]]
   
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#                                        Name                Industry   Revenue  \
# 0                                   Walmart                  Retail  $611,289
# 1                              Saudi Aramco             Oil and gas  $603,651
# 2           State Grid Corporation of China             Electricity  $530,009
# 3                                    Amazon                  Retail  $513,983
# 4                                     Vitol             Commodities  $505,000
# 5      China National Petroleum Corporation             Oil and gas  $483,019
# 6           China Petrochemical Corporation             Oil and gas  $471,154
# 7                                ExxonMobil             Oil and gas  $413,680
# 8                                     Apple             Electronics  $394,328
# 9                                     Shell             Oil and gas  $386,201
# 10                       UnitedHealth Group              Healthcare  $324,162
# ...

# %%
df.to_csv(r'/Users/lindawang/Desktop/Techlent/Week13/Companies.csv')
